# %% [markdown]
# <a href="https://colab.research.google.com/github/sde2424242424-coder/2026_spring_assignments/blob/main/API_26_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lecture #1: Review

# %% [markdown]
# requests 모듈을 사용하면 Web API에 쉽게 요청을 보낼 수 있다. GET 메서드는 데이터를 가져올 때 사용된다. 서버의 응답은 status_code를 통해 확인할 수 있다. 서버가 JSON을 반환하면 response.json()을 사용하여 Python 딕셔너리로 변환할 수 있다.

# %%
import requests

url = "https://jsonplaceholder.typicode.com/posts/1"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response Text:", response.text)
print("JSON Data:", response.json())
# Out:
# Status Code: 200
# Response Text: {
#   "userId": 1,
#   "id": 1,
#   "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#   "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }
# JSON Data: {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %% [markdown]
# Lecture #2: Exercises

# %% [markdown]
# 4. Naver와 Google의 Server 헤더 비교

# %% [markdown]
# 이 코드는 Naver와 Google 서버의 응답 헤더를 비교한다.

# %%
import requests

urls = {
    "Naver": "https://www.naver.com",
    "Google": "https://www.google.com"
}

for name, url in urls.items():
    try:
        response = requests.get(url, timeout=10)

        print(f"\n{name}")
        print(f"URL: {url}")
        print(f"Status Code: {response.status_code}")

        server_header = response.headers.get("Server", "Server header not found")
        content_type = response.headers.get("Content-Type", "Content-Type not found")
        date_header = response.headers.get("Date", "Date header not found")

        print(f"Server: {server_header}")
        print(f"Content-Type: {content_type}")
        print(f"Date: {date_header}")

    except requests.exceptions.RequestException as e:
        print(f"\n{name}")
        print(f"Error: {e}")
# Out:
# Naver
# URL: https://www.naver.com
# Status Code: 200
# Server: nfront
# Content-Type: text/html; charset=UTF-8
# Date: Sat, 28 Mar 2026 09:55:30 GMT
#
# Google
# URL: https://www.google.com
# Status Code: 200
# Server: gws
# Content-Type: text/html; charset=ISO-8859-1
# Date: Sat, 28 Mar 2026 09:55:30 GMT

# %% [markdown]
# 5. users JSON을 불러와 DataFrame에 저장하고, address를 별도의 DataFrame으로 변환하기

# %% [markdown]
# 이 코드는 API에서 JSON 데이터를 가져와 Pandas DataFrame으로 변환한다.

# %%
import requests
import pandas as pd

url = "https://jsonplaceholder.typicode.com/users"

response = requests.get(url)
data = response.json()

df = pd.DataFrame(data)

print("=== Original DataFrame ===")
print(df)
print()

address_df = pd.DataFrame(df["address"].tolist())

print("=== Address DataFrame ===")
print(address_df)
# Out:
# === Original DataFrame ===
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
# 5  {'street': 'Norberto Crossing', 'suite': 'Apt....   1-477-935-8478 x6430
# 6  {'street': 'Rex Trail', 'suite': 'Suite 280', ...           210.067.6132
# 7  {'street': 'Ellsworth Summit', 'suite': 'Suite...      586.493.6943 x140
# 8  {'street': 'Dayna Park', 'suite': 'Suite 449',...   (775)976-6794 x41206
# 9  {'street': 'Kattie Turnpike', 'suite': 'Suite ...           024-648-3804
#
#          website                                            company
# 0  hildegard.org  {'name': 'Romaguera-Crona', 'catchPhrase': 'Mu...
# 1  anastasia.net  {'name': 'Deckow-Crist', 'catchPhrase': 'Proac...
# 2    ramiro.info  {'name': 'Romaguera-Jacobson', 'catchPhrase': ...
# 3       kale.biz  {'name': 'Robel-Corkery', 'catchPhrase': 'Mult...
# 4   demarco.info  {'name': 'Keebler LLC', 'catchPhrase': 'User-c...
# 5        ola.org  {'name': 'Considine-Lockman', 'catchPhrase': '...
# 6       elvis.io  {'name': 'Johns Group', 'catchPhrase': 'Config...
# 7   jacynthe.com  {'name': 'Abernathy Group', 'catchPhrase': 'Im...
# 8     conrad.com  {'name': 'Yost and Sons', 'catchPhrase': 'Swit...
# 9    ambrose.net  {'name': 'Hoeger LLC', 'catchPhrase': 'Central...
#
# === Address DataFrame ===
#               street      suite            city     zipcode  \
# 0        Kulas Light   Apt. 556     Gwenborough  92998-3874
# 1      Victor Plains  Suite 879     Wisokyburgh  90566-7771
# 2  Douglas Extension  Suite 847   McKenziehaven  59590-4157
# 3        Hoeger Mall   Apt. 692     South Elvis  53919-4257
# 4       Skiles Walks  Suite 351      Roscoeview       33263
# 5  Norberto Crossing   Apt. 950   South Christy  23505-1337
# 6          Rex Trail  Suite 280       Howemouth  58804-1099
# 7   Ellsworth Summit  Suite 729       Aliyaview       45169
# 8         Dayna Park  Suite 449  Bartholomebury  76495-3109
# 9    Kattie Turnpike  Suite 198     Lebsackbury  31428-2261
#
#                                        geo
# 0    {'lat': '-37.3159', 'lng': '81.1496'}
# 1   {'lat': '-43.9509', 'lng': '-34.4618'}
# 2   {'lat': '-68.6102', 'lng': '-47.0653'}
# 3   {'lat': '29.4572', 'lng': '-164.2990'}
# 4    {'lat': '-31.8129', 'lng': '62.5342'}
# 5    {'lat': '-71.4197', 'lng': '71.7478'}
# 6     {'lat': '24.8918', 'lng': '21.8984'}
# 7  {'lat': '-14.3990', 'lng': '-120.7677'}
# 8   {'lat': '24.6463', 'lng': '-168.8889'}
# 9    {'lat': '-38.2386', 'lng': '57.2232'}

# %% [markdown]
# 6. posts를 불러와 짝수 인덱스를 선택한 뒤 Excel에 저장하기

# %% [markdown]
# 이 코드는 게시물 데이터를 불러오고, 짝수 인덱스의 행을 선택하여 Excel에 저장한다.

# %%
import requests
import pandas as pd

url = "https://jsonplaceholder.typicode.com/posts"

response = requests.get(url)
data = response.json()

df = pd.DataFrame(data)

even_index_df = df[df.index % 2 == 0]

file_name = "even_index_posts.xlsx"
even_index_df.to_excel(file_name, index=False)

print("Even index rows:")
print(even_index_df)
print()
print(f"Excel file saved as: {file_name}")
# Out:
# Even index rows:
#     userId  id                                              title  \
# 0        1   1  sunt aut facere repellat provident occaecati e...
# 2        1   3  ea molestias quasi exercitationem repellat qui...
# 4        1   5                                 nesciunt quas odio
# 6        1   7                               magnam facilis autem
# 8        1   9  nesciunt iure omnis dolorem tempora et accusan...
# 10       2  11                   et ea vero quia laudantium autem
# 12       2  13  dolorum ut in voluptas mollitia et saepe quo a...
# 14       2  15                            eveniet quod temporibus
# 16       2  17  fugit voluptas sed molestias voluptatem provident
# 18       2  19          adipisci placeat illum aut reiciendis qui
# 20       3  21  asperiores ea ipsam voluptatibus modi minima q...
# 22       3  23                      maxime id vitae nihil numquam
# 24       3  25                      rem alias distinctio quo quis
# 26       3  27              quasi id et eos tenetur aut quo autem
# 28       3  29            iusto eius quod necessitatibus culpa ea
# 30       4  31            ullam ut quidem id aut vel consequuntur
# 32       4  33                    qui explicabo molestiae dolorem
# 34       4  35     id nihil consequatur molestias animi provident
# 36       4  37                   provident vel ut sit ratione est
# 38       4  39        eos dolorem iste accusantium est eaque quam
# 40       5  41                                     non est facere
# 42       5  43  eligendi iste nostrum consequuntur adipisci pr...
# 44       5  45  ut numquam possimus omnis eius suscipit laudan...
# 46       5  47                  quibusdam cumque rem aut deserunt
# 48       5  49  laborum non sunt aut ut assumenda perspiciatis...
# 50       6  51  soluta aliquam aperiam consequatur illo quis v...
# 52       6  53                           ut quo aut ducimus alias
# 54       6  55                   sit vel voluptatem et non libero
# 56       6  57                                     sed ab est est
# 58       6  59  qui commodi dolor at maiores et quis id accusa...
# 60       7  61    voluptatem doloribus consectetur est ut ducimus
# 62       7  63  voluptas blanditiis repellendus animi ducimus ...
# 64       7  65                     consequatur id enim sunt et et
# 66       7  67        aliquid eos sed fuga est maxime repellendus
# 68       7  69                   fugiat quod pariatur odit minima
# 70       8  71                  et iusto veniam et illum aut fuga
# 72       8  73  consequuntur deleniti eos quia temporibus ab a...
# 74       8  75       dignissimos eum dolor ut enim et delectus in
# 76       8  77           necessitatibus quasi exercitationem odio
# 78       8  79  pariatur consequatur quia magnam autem omnis n...
# 80       9  81    tempora rem veritatis voluptas quo dolores vero
# 82       9  83         odit et voluptates doloribus alias odio et
# 84       9  85  dolore veritatis porro provident adipisci blan...
# 86       9  87                         nostrum quis quasi placeat
# 88       9  89           sint soluta et vel magnam aut ut sed qui
# 90      10  91                                       aut amet sed
# 92      10  93                           beatae soluta recusandae
# 94      10  95              id minus libero illum nam ad officiis
# 96      10  97         quas fugiat ut perspiciatis vero provident
# 98      10  99  temporibus sit alias delectus eligendi possimu...
#
#                                                  body
# 0   quia et suscipit\nsuscipit recusandae consequu...
# 2   et iusto sed quo iure\nvoluptatem occaecati om...
# 4   repudiandae veniam quaerat sunt sed\nalias aut...
# 6   dolore placeat quibusdam ea quo vitae\nmagni q...
# 8   consectetur animi nesciunt iure dolore\nenim q...
# 10  delectus reiciendis molestiae occaecati non mi...
# 12  aut dicta possimus sint mollitia voluptas comm...
# 14  reprehenderit quos placeat\nvelit minima offic...
# 16  eos voluptas et aut odit natus earum\naspernat...
# 18  illum quis cupiditate provident sit magnam\nea...
# 20  repellat aliquid praesentium dolorem quo\nsed ...
# 22  veritatis unde neque eligendi\nquae quod archi...
# 24  ullam consequatur ut\nomnis quis sit vel conse...
# 26  eum sed dolores ipsam sint possimus debitis oc...
# 28  odit magnam ut saepe sed non qui\ntempora atqu...
# 30  debitis eius sed quibusdam non quis consectetu...
# 32  rerum ut et numquam laborum odit est sit\nid q...
# 34  nisi error delectus possimus ut eligendi vitae...
# 36  debitis et eaque non officia sed nesciunt pari...
# 38  corporis rerum ducimus vel eum accusantium\nma...
# 40  molestias id nostrum\nexcepturi molestiae dolo...
# 42  similique fugit est\nillum et dolorum harum et...
# 44  est natus reiciendis nihil possimus aut provid...
# 46  voluptatem assumenda ut qui ut cupiditate aut ...
# 48  inventore ab sint\nnatus fugit id nulla sequi ...
# 50  sunt dolores aut doloribus\ndolore doloribus v...
# 52  minima harum praesentium eum rerum illo dolore...
# 54  debitis excepturi ea perferendis harum libero ...
# 56  at pariatur consequuntur earum quidem\nquo est...
# 58  perspiciatis et quam ea autem temporibus non v...
# 60  ab nemo optio odio\ndelectus tenetur corporis ...
# 62  enim adipisci aspernatur nemo\nnumquam omnis f...
# 64  voluptatibus ex esse\nsint explicabo est aliqu...
# 66  reprehenderit id nostrum\nvoluptas doloremque ...
# 68  officiis error culpa consequatur modi asperior...
# 70  occaecati a doloribus\niste saepe consectetur ...
# 72  voluptatem cumque tenetur consequatur expedita...
# 74  commodi non non omnis et voluptas sit\nautem a...
# 76  modi ut in nulla repudiandae dolorum nostrum e...
# 78  libero accusantium et et facere incidunt sit d...
# 80  facere qui nesciunt est voluptatum voluptatem ...
# 82  est molestiae facilis quis tempora numquam nih...
# 84  similique sed nisi voluptas iusto omnis\nmolli...
# 86  eos et molestiae\nnesciunt ut a\ndolores persp...
# 88  repellat aut aperiam totam temporibus autem et...
# 90  libero voluptate eveniet aperiam sed\nsunt pla...
# 92  dolorem quibusdam ducimus consequuntur dicta a...
# 94  earum voluptatem facere provident blanditiis v...
# 96  eum non blanditiis soluta porro quibusdam volu...
# 98  quo deleniti praesentium dicta non quod\naut e...
#
# Excel file saved as: even_index_posts.xlsx

# %% [markdown]
# 7. Gradio UI: userId를 입력하고 posts를 실시간으로 필터링하기

# %% [markdown]
# 이 코드는 Gradio로 간단한 인터페이스를 생성하며, 사용자가 userId를 입력하면 해당하는 데이터만 보여준다.

# %%
import requests
import pandas as pd
import gradio as gr

def get_posts(user_id):
    url = "https://jsonplaceholder.typicode.com/posts"

    params = {"userId": user_id}

    response = requests.get(url, params=params)
    data = response.json()

    df = pd.DataFrame(data)
    return df

iface = gr.Interface(
    fn=get_posts,
    inputs=gr.Number(label="Enter userId"),
    outputs=gr.Dataframe(label="Filtered Posts"),
    title="Posts Filter by userId",
    description="Enter a userId to filter posts in real time"
)

iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://95ffb0c1e2797e67a6.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://95ffb0c1e2797e67a6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# 8. CSV를 불러오고 병합한 뒤 Gradio로 시각화하기

# %% [markdown]
# 링크를 통해 CSV 파일을 불러오고 이를 DataFrame으로 변환한다.

# %%
import pandas as pd
import gradio as gr
import csv

def load_file(path):
    encodings = ["cp949", "euc-kr", "utf-8", "utf-8-sig"]

    for enc in encodings:
        try:
            df = pd.read_csv(
                path,
                encoding=enc,
                engine="python",
                on_bad_lines="skip",
                quoting=csv.QUOTE_MINIMAL
            )
            print(f"{path} loaded with {enc}")
            return df
        except:
            continue

    raise Exception(f"Cannot read file: {path}")


df1 = load_file("서울특별시 공공자전거 이용정보(일별)_2510.csv")
df2 = load_file("서울특별시 공공자전거 이용정보(일별)_2511.csv")
df3 = load_file("서울특별시 공공자전거 이용정보(일별)_2512.csv")


merged_df = pd.concat([df1, df2, df3], ignore_index=True)

print(merged_df.head())
print(merged_df.columns)

def show_data(n_rows):
    return merged_df.head(int(n_rows))

iface = gr.Interface(
    fn=show_data,
    inputs=gr.Number(label="Number of rows"),
    outputs=gr.Dataframe(label="Merged Data"),
    title="Seoul Bike Data Viewer"
)

iface.launch()
# Out:
# 서울특별시 공공자전거 이용정보(일별)_2510.csv loaded with cp949
# 서울특별시 공공자전거 이용정보(일별)_2511.csv loaded with cp949
# 서울특별시 공공자전거 이용정보(일별)_2512.csv loaded with cp949
#          대여일자  대여소번호                대여소 대여구분코드   성별   연령대   이용건수    운동량   탄소량  \
# 0  2025-10-01    739         739. 신월사거리    정기권  NaN  ~10대      1  58.63  0.51
# 1  2025-10-01   1024      1024.  강동구청 앞    정기권  NaN  ~10대      1  46.08  0.42
# 2  2025-10-01   1964      1964. 원메디타운 앞    정기권  NaN  ~10대      1  18.89  0.28
# 3  2025-10-01   1966  1966. 한마을아파트 정문상가    정기권  NaN  ~10대      1  14.26  0.21
# 4  2025-10-01   1160  1160. 양천향교역 7번출구앞    정기권  NaN  ~10대      1  12.89  0.14
#
#    이동거리(M)  이용시간(분)
# 0  2209.88       15
# 1  1790.06       15
# 2  1192.45        9
# 3   899.94        4
# 4   591.77        3
# Index(['대여일자', '대여소번호', '대여소', '대여구분코드', '성별', '연령대', ' 이용건수', '운동량', '탄소량',
#        '이동거리(M)', '이용시간(분)'],
#       dtype='object')
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://90ad46e31acbc80c4d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://90ad46e31acbc80c4d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# 9. Gemini API / Agent AI (UI를 통한 번역)

# %% [markdown]
# 함수는 텍스트를 입력받아 번역 결과를 반환한다.

# %%
import gradio as gr

def translate_text(text):

    translations = {
        "hello": "안녕하세요",
        "thank you": "감사합니다",
        "goodbye": "안녕히 가세요"
    }

    return translations.get(text.lower(), "Translation not found")

iface = gr.Interface(
    fn=translate_text,
    inputs=gr.Textbox(label="Enter English text"),
    outputs=gr.Textbox(label="Korean Translation"),
    title="Simple Translator (No API)",
    description="Translate basic English words to Korean"
)

iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://3d12a08696780bc8b0.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3d12a08696780bc8b0.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# 10. Hugging Face: 멀티모달 LLM을 사용해보기

# %% [markdown]
# Transformers 라이브러리의 pipeline()을 연결한다. 이는 Hugging Face의 사전 학습된 모델을 빠르게 추론(inference)에 사용하는 표준적인 방법이다.

# %%
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration

model_name = "Salesforce/blip-image-captioning-base"

processor = BlipProcessor.from_pretrained(model_name)
model = BlipForConditionalGeneration.from_pretrained(model_name)

img_url = "https://huggingface.co/datasets/Narsil/image_dummy/raw/main/parrots.png"
raw_image = Image.open(requests.get(img_url, stream=True).raw).convert("RGB")

inputs = processor(raw_image, return_tensors="pt")
out = model.generate(**inputs)

caption = processor.decode(out[0], skip_special_tokens=True)
print(caption)
# Out:
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie text_decoder.cls.predictions.bias to text_decoder.cls.predictions.decoder.bias, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie text_decoder.bert.embeddings.word_embeddings.weight to text_decoder.cls.predictions.decoder.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# BlipForConditionalGeneration LOAD REPORT from: Salesforce/blip-image-captioning-base
# Key                                       | Status     |  |
# ------------------------------------------+------------+--+-
# text_decoder.bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# two birds are standing next to each other birds

# %% [markdown]
# 11. Reachy Mini 관련 영상 시청

# %% [markdown]
# 이 과제는 오픈소스 AI 장치의 예시를 이해하기 위한 것이다.
# 이 영상은 AI가 화면 속 프로그램뿐만 아니라 물리적인 장치인 동반 로봇에서도 어떻게 활용될 수 있는지를 보여준다.
# Reachy Mini는 실험, 학습 및 개발을 위한 오픈 플랫폼으로 소개된다.
